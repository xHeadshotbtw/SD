# %% [markdown]
# <a href="https://colab.research.google.com/github/xHeadshotbtw/HS-Stable-Diffusion-WebUI/blob/main/HS'%20Stable%20Diffusion%20WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HS' Stable Diffusion WebUI**
# The best and most complete Stable Diffusion WebUI Colab Notebook
#
# Adapted from [camenduru](https://github.com/camenduru/stable-diffusion-webui-colab)
#
# Latest Notebook update [here](https://github.com/xHeadshotbtw/HS-Stable-Diffusion-WebUI)

# %%
#@title #Download SD and install dependencies
#@markdown Install Stable diffusion + Extensions
# %cd /content

# %env TF_CPP_MIN_LOG_LEVEL=1

# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb

# !apt -y install -qq aria2
# !pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 --extra-index-url https://download.pytorch.org/whl/cu116 -U
# !pip install -q xformers==0.0.16 triton==2.0.0 -U

# !git clone -b v2.1 https://github.com/camenduru/stable-diffusion-webui
# !git clone https://huggingface.co/embed/negative /content/stable-diffusion-webui/embeddings/negative
# !git clone https://huggingface.co/embed/lora /content/stable-diffusion-webui/models/Lora/positive
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d /content/stable-diffusion-webui/models/ESRGAN -o 4x-UltraSharp.pth
# !wget https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py -O /content/stable-diffusion-webui/scripts/run_n_times.py
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui
# !git clone https://github.com/camenduru/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
# !git clone https://github.com/camenduru/stable-diffusion-webui-huggingface /content/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface
# !git clone https://github.com/camenduru/sd-civitai-browser /content/stable-diffusion-webui/extensions/sd-civitai-browser
# !git clone https://github.com/kohya-ss/sd-webui-additional-networks /content/stable-diffusion-webui/extensions/sd-webui-additional-networks
# !git clone https://github.com/Mikubill/sd-webui-controlnet /content/stable-diffusion-webui/extensions/sd-webui-controlnet
# !git clone https://github.com/fkunn1326/openpose-editor /content/stable-diffusion-webui/extensions/openpose-editor
# !git clone https://github.com/jexom/sd-webui-depth-lib /content/stable-diffusion-webui/extensions/sd-webui-depth-lib
# !git clone https://github.com/hnmr293/posex /content/stable-diffusion-webui/extensions/posex
# !git clone https://github.com/camenduru/sd-webui-tunnels /content/stable-diffusion-webui/extensions/sd-webui-tunnels
# !git clone https://github.com/etherealxx/batchlinks-webui /content/stable-diffusion-webui/extensions/batchlinks-webui
# !git clone https://github.com/camenduru/stable-diffusion-webui-catppuccin /content/stable-diffusion-webui/extensions/stable-diffusion-webui-catppuccin
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-webui-locon /content/stable-diffusion-webui/extensions/a1111-sd-webui-locon
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-rembg /content/stable-diffusion-webui/extensions/stable-diffusion-webui-rembg
# !git clone https://github.com/ashen-sensored/stable-diffusion-webui-two-shot /content/stable-diffusion-webui/extensions/stable-diffusion-webui-two-shot
# !git clone https://github.com/camenduru/sd_webui_stealth_pnginfo /content/stable-diffusion-webui/extensions/sd_webui_stealth_pnginfo
# !git clone https://github.com/pkuliyi2015/multidiffusion-upscaler-for-automatic1111 /content/stable-diffusion-webui/extensions/multidiffusion-upscaler-for-automatic1111
# !git clone https://github.com/Bing-su/dddetailer /content/stable-diffusion-webui/extensions/dddetailer
# !git clone https://github.com/richrobber2/canvas-zoom /content/stable-diffusion-webui/extensions/canvas-zoom
# %cd /content/stable-diffusion-webui
# !git reset --hard
# !git -C /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai reset --hard


# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Akumetsu971/SD_Anime_Futuristic_Armor/resolve/main/4x_fatal_Anime_500000_G.pth -d /content/stable-diffusion-webui/models/ESRGAN -o 4x_Fatal-Anime.pth

# %%
#@title #Realistic Models
#@markdown Choose the models you want
App_IconsGenerator = False #@param {'type':'boolean'}
Lyriel = False #@param {'type':'boolean'}
Realistic_Vision = False #@param {'type':'boolean'}
Deliberate = False #@param {'type':'boolean'}
Chilloutmix_NiPrunedFp32Fix = False #@param {'type':'boolean'}
ProtogenX53Photorealism = False #@param {'type':'boolean'}
SD_v21_nonema_pruned = False #@param {'type':'boolean'}
SD_v21_ema_pruned = False #@param {'type':'boolean'}
TShirtPrintDesigns = False #@param {'type':'boolean'}
MagifactoryTShirtModel = False #@param {'type':'boolean'}


# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/vae/diffusion_pytorch_model.safetensors -d /content/stable-diffusion-webui/models/VAE -o SD-vae-ig.safetensors


if App_IconsGenerator:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/20 -d /content/stable-diffusion-webui/models/Stable-diffusion -o appIconsGenerator_v1.ckpt

if Lyriel:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/46658 -d /content/stable-diffusion-webui/models/Stable-diffusion -o lyriel_v14.safetensors

if Realistic_Vision:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/29460 -d /content/stable-diffusion-webui/models/Stable-diffusion -o realisticVisionV20.safetensors

if Deliberate:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15236 -d /content/stable-diffusion-webui/models/Stable-diffusion -o deliberate_v2.safetensors

if Chilloutmix_NiPrunedFp32Fix:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/11745 -d /content/stable-diffusion-webui/models/Stable-diffusion -o chilloutmix_NiPrunedFp32Fix.safetensors

if ProtogenX53Photorealism:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/4229 -d /content/stable-diffusion-webui/models/Stable-diffusion -o protogenX53Photorealism_10.safetensors

if SD_v21_nonema_pruned:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-nonema-pruned.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o v2-1_768-nonema-pruned.safetensors

if SD_v21_ema_pruned:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o v2-1_768-ema-pruned.safetensors

if TShirtPrintDesigns:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6098 -d /content/stable-diffusion-webui/models/Stable-diffusion -o tShirtPrintDesignsTest_v01.ckpt

if MagifactoryTShirtModel:
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7554 -d /content/stable-diffusion-webui/models/Stable-diffusion -o MAGIFACTORYTShirt_magifactoryTShirtModel.safetensors

# %%
#@title #Anime Models
#@markdown Choose the models you want
AOM3A1 = False #@param {'type':'boolean'}
AOM3A1B = False #@param {'type':'boolean'}
AOM3A2 = False #@param {'type':'boolean'}
AOM3A3 = False #@param {'type':'boolean'}
AOM3 = False #@param {'type':'boolean'}
AbyssOrangeMix2_nsfw = False #@param {'type':'boolean'}
AbyssOrangeMix2_hard = False #@param {'type':'boolean'}
AnythingV45 = False #@param {'type':'boolean'}
AnythingV5 = False #@param {'type':'boolean'}
NovelAI = False #@param {'type':'boolean'}
CetusMix_Version35 = False #@param {'type':'boolean'}
CetusMix_CodaV2 = False #@param {'type':'boolean'}
CetusMix_WhaleFall = False #@param {'type':'boolean'}
MIXProV4 = False #@param {'type':'boolean'}
CoreMixPureV1 = False #@param {'type':'boolean'}
EndlessMixV35 = False #@param {'type':'boolean'}
LonganMix = False #@param {'type':'boolean'}
AnyPastel = False #@param {'type':'boolean'}
Pastelmix_better_vae = False #@param {'type':'boolean'}
Pastelmix_pruned_fp16 = False #@param {'type':'boolean'}
CounterfeitV25_pruned = False #@param {'type':'boolean'}
CounterfeitV25_fp16 = False #@param {'type':'boolean'}
GrapeFruitHentaiModelv41 = False #@param {'type':'boolean'}
HassakuHentaiModel = False #@param {'type':'boolean'}
EerieOrangeMix2Hardcore = False #@param {'type':'boolean'}
Corneos7thHeavenMix_v2 = False #@param {'type':'boolean'}
OrangeCoCoa5050Mix = False #@param {'type':'boolean'}
ReplicantV2_fp32 = False #@param {'type':'boolean'}
MeinaHentai_v21 = False #@param {'type':'boolean'}
Meinamix_MeinaV9 = False #@param {'type':'boolean'}
MeinaPastel_V4 = False #@param {type:"boolean"}
AndromedaMix_Version2 = False #@param {'type':'boolean'}
BettermixAnime_v2 = False #@param {'type':'boolean'}
UnstableInkDream_Balance = False #@param {'type':'boolean'}
UnstableInkDream_Anime = False #@param {'type':'boolean'}
YoZoRaV1_origin = False #@param {'type':'boolean'}
YoZoRaV1_purned_fp16 = False #@param {'type':'boolean'}
DarkSushiMixMix_BrighterPruned = False #@param {'type':'boolean'}
DarkSushiMixMix_DarkerPruned = False #@param {'type':'boolean'}


if AOM3A1:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/11813 -d /content/stable-diffusion-webui/models/Stable-diffusion -o AOM3A1.safetensors

if AOM3A1B:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/17233 -d /content/stable-diffusion-webui/models/Stable-diffusion -o AOM3A1B.safetensors
  
if AOM3A2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/11812 -d /content/stable-diffusion-webui/models/Stable-diffusion -o AOM3A2.safetensors
  
if AOM3A3:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/11811 -d /content/stable-diffusion-webui/models/Stable-diffusion -o AOM3A3.safetensors
  
if AOM3:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3_orangemixs.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o AOM3.safetensors
  
if AbyssOrangeMix2_nsfw:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5036 -d /content/stable-diffusion-webui/models/Stable-diffusion -o AbyssOrangeMix2_nsfw.safetensors
  
if AbyssOrangeMix2_hard:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_hard.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o AbyssOrangeMix2_hard.safetensors
  
if AnythingV45:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o anything-v4.5.safetensors
   
if AnythingV5:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/anything-v5.0/resolve/main/AnythingV5V3_v5PrtRE.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o AnythingV5V3_v5PrtRE.safetensors
  
if CetusMix_Version35:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/29851 -d /content/stable-diffusion-webui/models/Stable-diffusion -o cetusMix_Version35.safetensors
  
if MIXProV4:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/AIARTCHAN/MIX-Pro-V4/resolve/main/MIX-Pro-V4-fp16.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o MIX-Pro-V4-fp16.safetensors
   
if LonganMix:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Hemlok/LonganMix/resolve/main/LonganMix-fp16.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o LonganMix-fp16.safetensors
     
if AnyPastel:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/m4gnett/any-pastel/resolve/main/AnyPastel-hard-fp16.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o AnyPastel-hard-fp16.safetensors
   
if CoreMixPureV1:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/corechan/CoreMix/resolve/main/CoreMixPure-V1-fp32.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o CoreMixPure-V1-fp32.safetensors
     
if EndlessMixV35:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/teasan/endlessMix/resolve/main/model/v3/endlessMixV3.5.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o endlessMixV3.5.safetensors
   
if Pastelmix_better_vae:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-better-vae.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o pastelmix-better-vae.safetensors
  
if Pastelmix_pruned_fp16:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6297 -d /content/stable-diffusion-webui/models/Stable-diffusion -o pastelmix-pruned-fp16.safetensors
  
if CounterfeitV25_pruned:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5_pruned.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o Counterfeit-V2.5_pruned.safetensors
  
if CounterfeitV25_fp16:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5_fp16.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o Counterfeit-V2.5_fp16.safetensors
  
if GrapeFruitHentaiModelv41:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/29179 -d /content/stable-diffusion-webui/models/Stable-diffusion -o grapefruitHentaiModelv41.safetensors
  
if HassakuHentaiModel:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/37521 -d /content/stable-diffusion-webui/models/Stable-diffusion -o hassakuHentaiModel_v11.safetensors
    
if CetusMix_WhaleFall:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/36936 -d /content/stable-diffusion-webui/models/Stable-diffusion -o cetusMix_whalefall.safetensors

if EerieOrangeMix2Hardcore:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/9851 -d /content/stable-diffusion-webui/models/Stable-diffusion -o eerieorangemix2Hardcore.safetensors
  
if Corneos7thHeavenMix_v2:
  # !aria2c --console-log-level=errr -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6878 -d /content/stable-diffusion-webui/models/Stable-diffusion -o corneos7thHeavenMix_v2.safetensors
  
if OrangeCoCoa5050Mix:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/4938 -d /content/stable-diffusion-webui/models/Stable-diffusion -o orangecocoa5050Mix_110.safetensors
  
if ReplicantV2_fp32:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/gsdf/Replicant-V2.0/resolve/main/Replicant-V2.0_fp32.safetensors -d /content/stable-diffusion-webui/models/Stable-diffusion -o Replicant-V2.0_fp32.safetensors
  
if MeinaHentai_v21:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/26033 -d /content/stable-diffusion-webui/models/Stable-diffusion -o meinahentai_v21.safetensors
  
if Meinamix_MeinaV9:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/46137 -d /content/stable-diffusion-webui/models/Stable-diffusion -o meinamix_meinaV9.safetensors
  
if MeinaPastel_V4:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/27135 -d /content/stable-diffusion-webui/models/Stable-diffusion -o meinapastel_V3.safetensors
  
if AndromedaMix_Version2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7671 -d /content/stable-diffusion-webui/models/Stable-diffusion -o AndromedaMix_Version2.safetensors
  
if CetusMix_CodaV2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/48569 -d /content/stable-diffusion-webui/models/Stable-diffusion -o CetusMix_CodaV2.safetensors
  
if BettermixAnime_v2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/18183?type=Model&format=PickleTensor -d /content/stable-diffusion-webui/models/Stable-diffusion -o bettermixAnime_v20.ckpt
  
if UnstableInkDream_Balance:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/40626 -d /content/stable-diffusion-webui/models/Stable-diffusion -o unstableinkdream_75balance.safetensors
  
if UnstableInkDream_Anime:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/39859 -d /content/stable-diffusion-webui/models/Stable-diffusion -o unstableinkdream_75Anime.safetensors

if NovelAI:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/a1079602570/animefull-final-pruned/resolve/main/novelailatest-pruned.ckpt -d /content/stable-diffusion-webui/models/Stable-diffusion -o novelailatest-pruned.ckpt
  
if YoZoRaV1_origin:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/14459 -d /content/stable-diffusion-webui/models/Stable-diffusion -o nightSkyYOZORAStyle_yozoraV1Origin.safetensors

if YoZoRaV1_purned_fp16:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/14835 -d /content/stable-diffusion-webui/models/Stable-diffusion -o nightSkyYOZORAStyle_yozoraV1PurnedFp16.safetensors
  
if DarkSushiMixMix_BrighterPruned:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/33482 -d /content/stable-diffusion-webui/models/Stable-diffusion -o DarkSushiMixMix_BrighterPruned.safetensors

if DarkSushiMixMix_DarkerPruned:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/33488 -d /content/stable-diffusion-webui/models/Stable-diffusion -o DarkSushiMixMix_DarkerPruned.safetensors

# %%
#@title #VAEs
#@markdown Choose the vae you want
mse840000 = False #@param {'type':'boolean'}
Pastel_Waifu_Diffusion = False #@param {'type':'boolean'}
AnythingV4 = False #@param {'type':'boolean'}
NovelAIvae = False #@param {'type':'boolean'}
Counterfeit = False #@param {'type':'boolean'}
OrangeMix = False #@param {'type':'boolean'}
ClearVAE = False #@param {'type':'boolean'}
blessed2 = False #@param {'type':'boolean'}
AnythingV3 = False #@param {'type':'boolean'}
klf8_anime = False #@param {'type':'boolean'}
klf8_anime2 = False #@param {'type':'boolean'}
YOZORA_vae = False #@param {'type':'boolean'}



if mse840000:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/sp8999/test_VAE/resolve/main/mse840000_klf8anime_klf8anime2.vae.pt -d /content/stable-diffusion-webui/models/VAE -o mse840000_klf8anime_klf8anime2.vae.pt

if NovelAIvae:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/a1079602570/animefull-final-pruned/resolve/main/novelailatest-pruned.vae.pt -d /content/stable-diffusion-webui/models/VAE -o novelailatest-pruned.vae.pt

if Pastel_Waifu_Diffusion:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/29851?type=VAE -d /content/stable-diffusion-webui/models/VAE -o pastel-waifu-diffusion.vae.pt

if AnythingV4:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0.vae.pt -d /content/stable-diffusion-webui/models/VAE -o anything-v4.vae.pt

if Counterfeit:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5.vae.pt -d /content/stable-diffusion-webui/models/VAE -o Counterfeit.vae.pt

if OrangeMix:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt -d /content/stable-diffusion-webui/models/VAE -o orangemix.vae.pt

if AnythingV3:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt -d /content/stable-diffusion-webui/models/VAE -o anything-v3.vae.pt

if klf8_anime:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime.ckpt -d /content/stable-diffusion-webui/models/VAE -o kl-f8-anime.ckpt

if klf8_anime2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt -d /content/stable-diffusion-webui/models/VAE -o kl-f8-anime2.ckpt

if ClearVAE:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/26689 -d /content/stable-diffusion-webui/models/VAE -o clearvae_main.safetensors

if blessed2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/NoCrypt/blessed_vae/resolve/main/blessed2.vae.pt -d /content/stable-diffusion-webui/models/VAE -o blessed2.vae.pt

if YOZORA_vae:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/14459?type=VAE&format=Other -d /content/stable-diffusion-webui/models/VAE -o YOZORA.vae.pt

# %%
#@title #LoRa & Embeddings
#@markdown Choose the Lora and embedding type you want
Hentai = False #@param {'type':'boolean'}
Character = False #@param {'type':'boolean'}
Style = False #@param {'type':'boolean'}


#LORAs
if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7660 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o RezeChainsawMan.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/28295 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o monaGenshinImpact_v2.safetensors

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7719 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o kaomingStyleLora_kaomingStyleV1.safetensors

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/21123 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o mamimiArtworkStyle_v10.safetensors

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/8840 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o 1MbLORATrainedIn5MinsThatDoes_1.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/8002 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o hugeAssAndBoobs_v1.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/22057 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o murkysButtjobLora_1.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/22498 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o murkysCheekBulge_1.safetensors

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/13827 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o yoneyamaMaiStyle_yoneyamaMaiV1Lora.safetensors

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/26660 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o yoneyamaMaiStyle_yoneyamaMaiV2Locon.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15529 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o StandingDoggystyle_v11a.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/9048 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o shirtTugPoseLORA_shirtTug.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15496 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o NSFWTentaclesLora_v2Epochs20.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/8874 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o powerShapedPupils.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/9296 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o blueLockPupilsEyes_blPupils.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7852 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o kobeni_v10.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/11276 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o emptyEyesLoraUtsurome_v30.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15601 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o GenshenImpactYoimiya_10.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/9322 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o makimaEyesInpaint_csmakima.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/10029 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o ahegao_v1.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/8614 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o breastsOnGlass_v10.safetensors

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-lora.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o pastelmix-lora.safetensors

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/28907 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o animeLineartMangaLike_v30MangaLike.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/8531 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o yorBriarSpyFamily_lykonV1.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/11181 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o ganyuGenshinImpact_v20.safetensors

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7804 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o samdoesartsSamYang_offset.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/13601 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o MAPPA-like_StyleV0.5.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15024 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o MAPPA-like_StyleV1.0.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/33424 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o MAPPA-like_StyleV1.1.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/45570 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o MAPPA-like_StyleV1.2.safetensors

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/13091 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o beautifulSky.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/12304 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o JackOPose1.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/12235 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o JackOPose2.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/14628 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o xRayHentai25_xRayHentai25.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7336 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o fischlGenshinImpact.pt

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5842 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o dilucLorasCollections_dilucHard.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5876 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o lottalewdsBlowjobs_v1.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6964 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o lottalewdsBallsDeep_v1.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/18521 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o keqingGenshinImpact3in1_v10.safetensors

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6964 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o lottalewdsBallsDeep_v1.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5546 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o shenheLoraCollection_shenheHard.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/31772 -d /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora -o rezeChainsawManLora_v1.safetensors

#Embeddings

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/datasets/gsdf/EasyNegative/resolve/main/EasyNegative.pt -d /content/stable-diffusion-webui/embeddings -o EasyNegative.pt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/gsdf/Replicant-V1.0/resolve/main/re-badprompt.safetensors -d /content/stable-diffusion-webui/embeddings -o re-badprompt.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt.pt -d /content/stable-diffusion-webui/embeddings -o bad_prompt.pt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/AsciiP/badhandv4/resolve/main/badhandv4.pt -d /content/stable-diffusion-webui/embeddings -o badhandv4.pt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/yesyeahvh/bad-hands-5/resolve/main/bad-hands-5.pt -d /content/stable-diffusion-webui/embeddings -o bad-hands-5.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6080 -d /content/stable-diffusion-webui/embeddings -o Cross_Arms_Boobs.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6034 -d /content/stable-diffusion-webui/embeddings -o One_Arm_Boobs.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6318 -d /content/stable-diffusion-webui/embeddings -o X_Nipples.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6033 -d /content/stable-diffusion-webui/embeddings -o 2Hands_Boobs.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6526 -d /content/stable-diffusion-webui/embeddings -o Anal_Missionary.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5160 -d /content/stable-diffusion-webui/embeddings -o Anal_Behind_Pulling_Arms.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5235 -d /content/stable-diffusion-webui/embeddings -o Make-up.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6242 -d /content/stable-diffusion-webui/embeddings -o Blowjob_Side.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5051 -d /content/stable-diffusion-webui/embeddings -o Blowjob_POV.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5066 -d /content/stable-diffusion-webui/embeddings -o Dick_Between_Breasts.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7002 -d /content/stable-diffusion-webui/embeddings -o Ball_In_Mouth.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/4597 -d /content/stable-diffusion-webui/embeddings -o Anal.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/4738 -d /content/stable-diffusion-webui/embeddings -o CowGirl_Riding.pt

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6197 -d /content/stable-diffusion-webui/embeddings -o Makima.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5405 -d /content/stable-diffusion-webui/embeddings -o Missionary_Tied_Hands.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6770 -d /content/stable-diffusion-webui/embeddings -o Threesome.pt

if Hentai:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6128 -d /content/stable-diffusion-webui/embeddings -o Hentai_Stuff.pt

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6027 -d /content/stable-diffusion-webui/embeddings -o Power.pt

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/18187 -d /content/stable-diffusion-webui/embeddings -o hiten1.pt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/SirVeggie/nixeu_embeddings/resolve/main/nixeu_extra.pt -d /content/stable-diffusion-webui/embeddings -o nixeu_extra.pt

# %%
#@title #Enable ControlNet
#@markdown Check to enable ControlNet
ControlNet = False #@param {'type':'boolean'}


if ControlNet:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11e_sd15_ip2p_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11e_sd15_shuffle_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_canny_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_depth_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_depth_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_inpaint_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_lineart_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_mlsd_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_normalbae_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_openpose_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_scribble_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_seg_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_softedge_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11u_sd15_tile_fp16.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11u_sd15_tile_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_ip2p_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11e_sd15_ip2p_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_shuffle_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11e_sd15_shuffle_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_canny_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_canny_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_depth_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_depth_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_inpaint_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_inpaint_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_lineart_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_lineart_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_mlsd_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_mlsd_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_normalbae_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_normalbae_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_openpose_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_openpose_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_scribble_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_scribble_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_seg_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_seg_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_softedge_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15_softedge_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15s2_lineart_anime_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11u_sd15_tile_fp16.yaml -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_v11u_sd15_tile_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_style_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_style_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_sketch_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_seg_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_seg_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_openpose_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_openpose_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_keypose_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_keypose_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_depth_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_color_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_color_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd14v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_canny_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd15v2.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_canny_sd15v2.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd15v2.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_depth_sd15v2.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd15v2.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_sketch_sd15v2.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_zoedepth_sd15v1.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_zoedepth_sd15v1.pth

# %%
#@title #Start Stable Diffusion
#@markdown Run this cell to start Stable Diffusion

# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/stable-diffusion-webui/launch.py
# !sed -i -e 's/\"sd_model_checkpoint\"\,/\"sd_model_checkpoint\,sd_vae\,CLIP_stop_at_last_layers\"\,/g' /content/stable-diffusion-webui/modules/shared.py

# !mkdir /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui/models

# !python launch.py --listen --xformers --enable-insecure-extension-access --theme dark --gradio-queue --multiple --no-half-vae --disable-nan-check --share --cloudflared
