# %% [markdown]
# <a href="https://colab.research.google.com/github/xHeadshotbtw/SD/blob/main/Colab%20SD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title #Download Stable Diffusion and install dependencies
#@markdown Install Stable Diffusion + Extensions

mount_drive = False #@param {'type':'boolean'}

if mount_drive:
  from google.colab import drive
  drive.mount('/content/drive')

# %cd /content

# %env TF_CPP_MIN_LOG_LEVEL=1

# !apt -y update -qq
# !wget https://github.com/camenduru/gperftools/releases/download/v1.0/libtcmalloc_minimal.so.4 -O /content/libtcmalloc_minimal.so.4
# %env LD_PRELOAD=/content/libtcmalloc_minimal.so.4

# !apt -y install -qq aria2 libcairo2-dev pkg-config python3-dev
# !pip install -q torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U
# !pip install -q xformers==0.0.19 triton==2.0.0 -U

# !git clone https://github.com/xHeadshotbtw/HS
# !git clone https://github.com/xHeadshotbtw/controlnet /content/HS/extensions/controlnet
# !git clone https://github.com/xHeadshotbtw/sd-additional-networks /content/HS/extensions/sd-additional-networks
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/HS/extensions/deforum-for-automatic1111-webui
# !git clone https://github.com/etherealxx/batchlinks-webui /content/HS/extensions/batchlinks-webui
# !git clone https://github.com/camenduru/a1111-sd-webui-locon /content/HS/extensions/a1111-sd-webui-locon
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-webui-lycoris /content/HS/extensions/a1111-sd-webui-lycoris
# !git clone https://github.com/pkuliyi2015/multidiffusion-upscaler-for-automatic1111 /content/HS/extensions/multidiffusion-upscaler-for-automatic1111
# !git clone https://github.com/Bing-su/adetailer /content/HS/extensions/adetailer
# %cd /content/HS
# !git reset --hard
# !git -C /content/HS/repositories/stable-diffusion-stability-ai reset --hard

# !git clone https://github.com/pkuliyi2015/multidiffusion-upscaler-for-automatic1111 /content/HS/extensions/multidiffusion-upscaler-for-automatic1111


# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Zabin/Resizers/resolve/main/4x-UltraSharp.pth -d /content/HS/models/ESRGAN -o 4x-UltraSharp.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Akumetsu971/SD_Anime_Futuristic_Armor/resolve/main/4x_fatal_Anime_500000_G.pth -d /content/HS/models/ESRGAN -o 4x_Fatal-Anime.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/konohashinobi4/4xAnimesharp/resolve/main/4x-AnimeSharp.pth -d /content/HS/models/ESRGAN -o 4x-AnimeSharp.pth

# %%
#@title #Models
#@markdown Choose the models you want
Logo = False #@param {'type':'boolean'}
DareLites = False #@param {'type':'boolean'}
AOM3 = False #@param {'type':'boolean'}
AbyssOrangeMix2_hard = False #@param {'type':'boolean'}
AnythingV5 = False #@param {'type':'boolean'}
NovelAI = False #@param {'type':'boolean'}
CetusMix_v4 = False #@param {'type':'boolean'}
CetusMix_CodaV2 = False #@param {'type':'boolean'}
CetusMix_WhaleFall2 = False #@param {'type':'boolean'}
MIXProV4 = False #@param {'type':'boolean'}
CoreMixPureV1 = False #@param {'type':'boolean'}
LonganMix = False #@param {'type':'boolean'}
AnyPastel = False #@param {'type':'boolean'}
CounterfeitV3 = False #@param {'type':'boolean'}
GrapeFruitHentaiModelv41 = False #@param {'type':'boolean'}
HassakuHentaiModel = False #@param {'type':'boolean'}
ReplicantV2_fp32 = False #@param {'type':'boolean'}
Meinamix_MeinaV9 = False #@param {'type':'boolean'}
AndromedaMix_Version2 = False #@param {'type':'boolean'}
SD_Silicon29 = False #@param {'type':'boolean'}
BreakDomain_M2150 = False #@param {'type':'boolean'}
BreakDomain_I2428 = False #@param {'type':'boolean'}
YoZoRaV1_origin = False #@param {'type':'boolean'}
FaceBombMix = False #@param {'type':'boolean'}
DarkSushiMixMix_225D = False #@param {'type':'boolean'}
ExpMix_Line = False #@param {'type':'boolean'}
StuffyStuff = False #@param {'type':'boolean'}


if Logo:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/76533 -d /content/HS/models/Stable-diffusion -o Logo.safetensors

if DareLites:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/14301 -d /content/HS/models/Stable-diffusion -o DareLites.safetensors

if AOM3:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/11814 -d /content/HS/models/Stable-diffusion -o AOM3.safetensors

if AbyssOrangeMix2_hard:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_hard.safetensors -d /content/HS/models/Stable-diffusion -o AbyssOrangeMix2_hard.safetensors

if AnythingV5:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/anything-v5.0/resolve/main/AnythingV5V3_v5PrtRE.safetensors -d /content/HS/models/Stable-diffusion -o AnythingV5V3_v5PrtRE.safetensors

if CetusMix_v4:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/78676 -d /content/HS/models/Stable-diffusion -o cetusMix_v4.safetensors

if MIXProV4:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/34559 -d /content/HS/models/Stable-diffusion -o MIXProV4.safetensors

if LonganMix:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Hemlok/LonganMix/resolve/main/LonganMix-fp16.safetensors -d /content/HS/models/Stable-diffusion -o LonganMix-fp16.safetensors

if AnyPastel:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/17701 -d /content/HS/models/Stable-diffusion -o AnyPastel.safetensors

if CoreMixPureV1:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/corechan/CoreMix/resolve/main/CoreMixPure-V1-fp32.safetensors -d /content/HS/models/Stable-diffusion -o CoreMixPure-V1-fp32.safetensors

if CounterfeitV3:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/57618 -d /content/HS/models/Stable-diffusion -o Counterfeit-V3.safetensors

if GrapeFruitHentaiModelv41:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/29179 -d /content/HS/models/Stable-diffusion -o grapefruitHentaiModelv41.safetensors

if HassakuHentaiModel:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/106922 -d /content/HS/models/Stable-diffusion -o hassakuHentaiModel_v11.safetensors

if CetusMix_WhaleFall2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/105924 -d /content/HS/models/Stable-diffusion -o cetusMix_whalefall2.safetensors

if ReplicantV2_fp32:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/gsdf/Replicant-V2.0/resolve/main/Replicant-V2.0_fp32.safetensors -d /content/HS/models/Stable-diffusion -o Replicant-V2.0_fp32.safetensors

if Meinamix_MeinaV9:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/46137 -d /content/HS/models/Stable-diffusion -o meinamix_meinaV9.safetensors

if AndromedaMix_Version2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7671 -d /content/HS/models/Stable-diffusion -o AndromedaMix_Version2.safetensors

if CetusMix_CodaV2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/48569 -d /content/HS/models/Stable-diffusion -o CetusMix_CodaV2.safetensors

if SD_Silicon29:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/86321 -d /content/HS/models/Stable-diffusion -o SD_Silicon29.safetensors

if BreakDomain_M2150:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/70969?type=Model&format=SafeTensor&size=pruned&fp=fp16 -d /content/HS/models/Stable-diffusion -o BreakDomain_M2150.safetensors

if BreakDomain_I2428:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/96424?type=Model&format=SafeTensor&size=pruned&fp=fp16 -d /content/HS/models/Stable-diffusion -o BreakDomain_I2428.safetensors

if NovelAI:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/a1079602570/animefull-final-pruned/resolve/main/novelailatest-pruned.ckpt -d /content/HS/models/Stable-diffusion -o novelailatest-pruned.ckpt

if YoZoRaV1_origin:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/14459 -d /content/HS/models/Stable-diffusion -o nightSkyYOZORAStyle_yozoraV1Origin.safetensors

if FaceBombMix:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/25993 -d /content/HS/models/Stable-diffusion -o facebombmix_v1Bakedvae.safetensors

if DarkSushiMixMix_225D:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/101640 -d /content/HS/models/Stable-diffusion -o DarkSushiMixMix_225D.safetensors

if ExpMix_Line:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/71779 -d /content/HS/models/Stable-diffusion -o ExpmixLine_v3.safetensors

if StuffyStuff:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/113017 -d /content/HS/models/Stable-diffusion -o StuffyStuff_v5.safetensors

# %%
#@title #VAEs
#@markdown Choose the vae you want
mse840000 = False #@param {'type':'boolean'}
NovelAIvae = False #@param {'type':'boolean'}
Counterfeit = False #@param {'type':'boolean'}
OrangeMix = False #@param {'type':'boolean'}
ClearVAE = False #@param {'type':'boolean'}
blessed2 = False #@param {'type':'boolean'}
AnythingV3 = False #@param {'type':'boolean'}
klf8_anime = False #@param {'type':'boolean'}
klf8_anime2 = False #@param {'type':'boolean'}
YOZORA_vae = False #@param {'type':'boolean'}



if mse840000:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/sp8999/test_VAE/resolve/main/mse840000_klf8anime_klf8anime2.vae.pt -d /content/HS/models/VAE -o mse840000_klf8anime_klf8anime2.vae.pt

if NovelAIvae:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/a1079602570/animefull-final-pruned/resolve/main/novelailatest-pruned.vae.pt -d /content/HS/models/VAE -o novelailatest-pruned.vae.pt

if Counterfeit:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5.vae.pt -d /content/HS/models/VAE -o Counterfeit.vae.pt

if OrangeMix:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt -d /content/HS/models/VAE -o orangemix.vae.pt

if AnythingV3:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt -d /content/HS/models/VAE -o anything-v3.vae.pt

if klf8_anime:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime.ckpt -d /content/HS/models/VAE -o kl-f8-anime.ckpt

if klf8_anime2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt -d /content/HS/models/VAE -o kl-f8-anime2.ckpt

if ClearVAE:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/88156?type=VAE&format=Other -d /content/HS/models/VAE -o clearvae.safetensors

if blessed2:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/NoCrypt/blessed_vae/resolve/main/blessed2.vae.pt -d /content/HS/models/VAE -o blessed2.vae.pt

if YOZORA_vae:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/14459?type=VAE&format=Other -d /content/HS/models/VAE -o YOZORA.vae.pt

# %%
# @title ## **Custom Download Cell**
# @markdown ### **Download from Custom URLs**
# @markdown  *Supports Almost Any Direct URL*

import os
from google.colab import files

# @markdown  Models:
Custom_Model_1 = ""  # @param {'type': 'string'}
Custom_Model_2 = ""  # @param {'type': 'string'}
Custom_Model_3 = ""  # @param {'type': 'string'}
Custom_Model_4 = ""  # @param {'type': 'string'}
Custom_Model_5 = ""  # @param {'type': 'string'}

url_variables = [Custom_Model_1, Custom_Model_2, Custom_Model_3, Custom_Model_4, Custom_Model_5]

for i in range(1, 6):
    Murl = globals()[f'Custom_Model_{i}']
    if Murl != "":
        # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "$Murl" -d /content/HS/models/Stable-diffusion

# @markdown  LoRa:
Custom_LoRa_1 = ""  # @param {'type': 'string'}
Custom_LoRa_2 = ""  # @param {'type': 'string'}
Custom_LoRa_3 = ""  # @param {'type': 'string'}
Custom_LoRa_4 = ""  # @param {'type': 'string'}
Custom_LoRa_5 = ""  # @param {'type': 'string'}
Custom_LoRa_6 = ""  # @param {'type': 'string'}
Custom_LoRa_7 = ""  # @param {'type': 'string'}

url_variables = [Custom_LoRa_1, Custom_LoRa_2, Custom_LoRa_3, Custom_LoRa_4, Custom_LoRa_5, Custom_LoRa_6, Custom_LoRa_7]

for i in range(1, 8):
    Lurl = globals()[f'Custom_LoRa_{i}']
    if Lurl != "":
        # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "$Lurl" -d /content/HS/extensions/sd-additional-networks/models/lora


# @markdown  ###Import from Drive:

Import_from_Drive = False #@param {'type':'boolean'}

# @markdown  #####Copy your model or/and your LoRa folder path and paste it below

Models_path = ""  # @param {'type': 'string'}
LoRa_path = ""  # @param {'type': 'string'}

if Import_from_Drive:
    from google.colab import drive
    if not os.path.exists('/content/drive/MyDrive'):
        drive.mount('/content/drive')
        # !cp {Models_path}/. /content/HS/models/Stable-diffusion/.
        # !cp {LoRa_path}/. /content/HS/extensions/sd-additional-networks/models/lora/.

# %%
#@title #Install ControlNet
#@markdown Enable and install ControlNet
ControlNet = False #@param {'type':'boolean'}


if ControlNet:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11e_sd15_ip2p_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11e_sd15_shuffle_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_canny_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11f1p_sd15_depth_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_inpaint_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_lineart_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_mlsd_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_normalbae_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_openpose_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_scribble_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_seg_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_softedge_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors -d /content/HS/extensions/controlnet/models -o control_v11f1e_sd15_tile_fp16.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_ip2p_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11e_sd15_ip2p_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_shuffle_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11e_sd15_shuffle_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_canny_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_canny_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1p_sd15_depth_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11f1p_sd15_depth_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_inpaint_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_inpaint_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_lineart_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_lineart_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_mlsd_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_mlsd_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_normalbae_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_normalbae_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_openpose_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_openpose_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_scribble_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_scribble_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_seg_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_seg_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_softedge_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11p_sd15_softedge_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15s2_lineart_anime_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1e_sd15_tile_fp16.yaml -d /content/HS/extensions/controlnet/models -o control_v11f1e_sd15_tile_fp16.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_style_sd14v1.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_style_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd14v1.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_sketch_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_seg_sd14v1.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_seg_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_openpose_sd14v1.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_openpose_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_keypose_sd14v1.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_keypose_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd14v1.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_depth_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_color_sd14v1.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_color_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd14v1.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_canny_sd14v1.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd15v2.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_canny_sd15v2.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd15v2.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_depth_sd15v2.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd15v2.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_sketch_sd15v2.pth
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_zoedepth_sd15v1.pth -d /content/HS/extensions/controlnet/models -o t2iadapter_zoedepth_sd15v1.pth

# %%
#@title #LoRa, LyCORIS & Embeddings
#@markdown Choose the Lora, LyCORIS and Embedding type you want
Logo = False #@param {'type':'boolean'}
NSFW = False #@param {'type':'boolean'}
Character = False #@param {'type':'boolean'}
Style = False #@param {'type':'boolean'}

#LORAs
if Logo:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/61877 -d /content/HS/extensions/sd-additional-networks/models/lora -o AnyLogo.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/55466 -d /content/HS/extensions/sd-additional-networks/models/lora -o LogoGoTypes.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/26741 -d /content/HS/extensions/sd-additional-networks/models/lora -o ModernLogo.safetensors

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7660 -d /content/HS/extensions/sd-additional-networks/models/lora -o RezeChainsawMan.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5546 -d /content/HS/extensions/sd-additional-networks/models/lora -o shenheLoraCollection_shenheHard.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/31772 -d /content/HS/extensions/sd-additional-networks/models/lora -o rezeChainsawManLora_v1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/28295 -d /content/HS/extensions/sd-additional-networks/models/lora -o monaGenshinImpact_v2.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/17079 -d /content/HS/extensions/sd-additional-networks/models/lora -o signoraGenshinImpact_v25.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/18060 -d /content/HS/extensions/sd-additional-networks/models/lora -o aliceNikke_v30.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/8874 -d /content/HS/extensions/sd-additional-networks/models/lora -o powerShapedPupils.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/9296 -d /content/HS/extensions/sd-additional-networks/models/lora -o blueLockPupilsEyes_blPupils.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7852 -d /content/HS/extensions/sd-additional-networks/models/lora -o kobeni_v10.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/11276 -d /content/HS/extensions/sd-additional-networks/models/lora -o emptyEyesLoraUtsurome_v30.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15601 -d /content/HS/extensions/sd-additional-networks/models/lora -o GenshenImpactYoimiya_10.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/9322 -d /content/HS/extensions/sd-additional-networks/models/lora -o makimaEyesInpaint_csmakima.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/33327 -d /content/HS/extensions/sd-additional-networks/models/lora -o nilouGenshinImpact_nilouv2.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/21618 -d /content/HS/extensions/sd-additional-networks/models/lora -o NahidaGenshin_nahidav3.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/8531 -d /content/HS/extensions/sd-additional-networks/models/lora -o yorBriarSpyFamily_lykonV1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/11181 -d /content/HS/extensions/sd-additional-networks/models/lora -o ganyuGenshinImpact_v20.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7336 -d /content/HS/extensions/sd-additional-networks/models/lora -o fischlGenshinImpact.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5842 -d /content/HS/extensions/sd-additional-networks/models/lora -o dilucLorasCollections_dilucHard.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/18521 -d /content/HS/extensions/sd-additional-networks/models/lora -o keqingGenshinImpact3in1_v10.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/67536 -d /content/HS/extensions/sd-additional-networks/models/lora -o FemaleTitanV2.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/47443 -d /content/HS/extensions/sd-additional-networks/models/lora -o kujousara10_0.95dim32.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/13169 -d /content/HS/extensions/sd-additional-networks/models/lora -o Eula-Model.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/47454 -d /content/HS/extensions/sd-additional-networks/models/lora -o RaidenShogunLora1200.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/47455 -d /content/HS/extensions/sd-additional-networks/models/lora -o YaeMikoLora1200.safetensors

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7719 -d /content/HS/extensions/sd-additional-networks/models/lora -o kaomingStyleLora_kaomingStyleV1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/21123 -d /content/HS/extensions/sd-additional-networks/models/lora -o mamimiArtworkStyle_v10.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/8840 -d /content/HS/extensions/sd-additional-networks/models/lora -o 1MbLORATrainedIn5MinsThatDoes_1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/13827 -d /content/HS/extensions/sd-additional-networks/models/lora -o yoneyamaMaiStyle_yoneyamaMaiV1Lora.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/26660 -d /content/HS/extensions/sd-additional-networks/models/lora -o yoneyamaMaiStyle_yoneyamaMaiV2Locon.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-lora.safetensors -d /content/HS/extensions/sd-additional-networks/models/lora -o pastelmix-lora.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/28907 -d /content/HS/extensions/sd-additional-networks/models/lora -o animeLineartMangaLike_v30MangaLike.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7804 -d /content/HS/extensions/sd-additional-networks/models/lora -o samdoesartsSamYang_offset.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/13091 -d /content/HS/extensions/sd-additional-networks/models/lora -o beautifulSky.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7981 -d /content/HS/extensions/sd-additional-networks/models/lora -o ligne_claire_anime.safetensors

if NSFW:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/8002 -d /content/HS/extensions/sd-additional-networks/models/lora -o hugeAssAndBoobs_v1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/22057 -d /content/HS/extensions/sd-additional-networks/models/lora -o murkysButtjobLora_1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/22498 -d /content/HS/extensions/sd-additional-networks/models/lora -o murkysCheekBulge_1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15529 -d /content/HS/extensions/sd-additional-networks/models/lora -o StandingDoggystyle_v11a.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/9048 -d /content/HS/extensions/sd-additional-networks/models/lora -o shirtTugPoseLORA_shirtTug.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15496 -d /content/HS/extensions/sd-additional-networks/models/lora -o NSFWTentaclesLora_v2Epochs20.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/8464 -d /content/HS/extensions/sd-additional-networks/models/lora -o ConceptImpliedFellatio_ConceptImpliedFellatio.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/10029 -d /content/HS/extensions/sd-additional-networks/models/lora -o ahegao_v1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/8614 -d /content/HS/extensions/sd-additional-networks/models/lora -o breastsOnGlass_v10.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/17679 -d /content/HS/extensions/sd-additional-networks/models/lora -o reverseSuspended_rscongresslora.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/12304 -d /content/HS/extensions/sd-additional-networks/models/lora -o JackOPose1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/12235 -d /content/HS/extensions/sd-additional-networks/models/lora -o JackOPose2.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/14628 -d /content/HS/extensions/sd-additional-networks/models/lora -o xRayNSFW25_xRayNSFW25.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5876 -d /content/HS/extensions/sd-additional-networks/models/lora -o lottalewdsBlowjobs_v1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6964 -d /content/HS/extensions/sd-additional-networks/models/lora -o lottalewdsBallsDeep_v1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/82596 -d /content/HS/extensions/sd-additional-networks/models/lora -o FishnetBunnyV1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/20546 -d /content/HS/extensions/sd-additional-networks/models/lora -o masturbation-v1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/99733 -d /content/HS/extensions/sd-additional-networks/models/lora -o adjusting_clothes_ass_v0.1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/95221 -d /content/HS/extensions/sd-additional-networks/models/lora -o stuck_in_washing_machine_v0.1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/95073 -d /content/HS/extensions/sd-additional-networks/models/lora -o hand_on_anothers_head_v0.1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/106979 -d /content/HS/extensions/sd-additional-networks/models/lora -o cuddling_handjob_v0.1b.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/102653 -d /content/HS/extensions/sd-additional-networks/models/lora -o thigh_sex_v0.1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/62680 -d /content/HS/extensions/sd-additional-networks/models/lora -o grinding_v0.3a.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/108698 -d /content/HS/extensions/sd-additional-networks/models/lora -o projectile_cum_v0.2.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/106957 -d /content/HS/extensions/sd-additional-networks/models/lora -o dp_from_behind_v0.1b.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/102579 -d /content/HS/extensions/sd-additional-networks/models/lora -o skirt_tug_v0.1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/101282 -d /content/HS/extensions/sd-additional-networks/models/lora -o constricted_pupils_v0.2a.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/100343 -d /content/HS/extensions/sd-additional-networks/models/lora -o multiple_hands_v0.5.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/100523 -d /content/HS/extensions/sd-additional-networks/models/lora -o undressing_another_v0.5.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/101249 -d /content/HS/extensions/sd-additional-networks/models/lora -o pov_deepthroat_v0.1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/98938 -d /content/HS/extensions/sd-additional-networks/models/lora -o buttjob_v0.2.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/95522 -d /content/HS/extensions/sd-additional-networks/models/lora -o between_breasts_v0.1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/67448 -d /content/HS/extensions/sd-additional-networks/models/lora -o coils_v0.1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/54606 -d /content/HS/extensions/sd-additional-networks/models/lora -o caught_cheating_v0.3d.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/48983 -d /content/HS/extensions/sd-additional-networks/models/lora -o blacked_v1.5.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/45775 -d /content/HS/extensions/sd-additional-networks/models/lora -o blacked_underwear_v1.9.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/45799 -d /content/HS/extensions/sd-additional-networks/models/lora -o piperperrimeme_v2.0.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/21983 -d /content/HS/extensions/sd-additional-networks/models/lora -o BetterNipples.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/111100 -d /content/HS/extensions/sd-additional-networks/models/lora -o grabbing_anothers_hair_v0.1.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/110467 -d /content/HS/extensions/sd-additional-networks/models/lora -o sitting_handjob_v0.3.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/9769 -d /content/HS/extensions/sd-additional-networks/models/lora -o CrossedEyes.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/28564 -d /content/HS/extensions/sd-additional-networks/models/lora -o circle-glasses_v1.1.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/13601 -d /content/HS/extensions/sd-additional-networks/models/lora -o MAPPA-like_StyleV0.5.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15024 -d /content/HS/extensions/sd-additional-networks/models/lora -o MAPPA-like_StyleV1.0.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/33424 -d /content/HS/extensions/sd-additional-networks/models/lora -o MAPPA-like_StyleV1.1.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/45570 -d /content/HS/extensions/sd-additional-networks/models/lora -o MAPPA-like_StyleV1.2.safetensors

#Embeddings

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/datasets/gsdf/EasyNegative/resolve/main/EasyNegative.pt -d /content/HS/embeddings -o EasyNegative.pt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/gsdf/Replicant-V1.0/resolve/main/re-badprompt.safetensors -d /content/HS/embeddings -o re-badprompt.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt.pt -d /content/HS/embeddings -o bad_prompt.pt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/AsciiP/badhandv4/resolve/main/badhandv4.pt -d /content/HS/embeddings -o badhandv4.pt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/yesyeahvh/bad-hands-5/resolve/main/bad-hands-5.pt -d /content/HS/embeddings -o bad-hands-5.pt

if NSFW:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6080 -d /content/HS/embeddings -o Cross_Arms_Boobs.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6034 -d /content/HS/embeddings -o One_Arm_Boobs.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6318 -d /content/HS/embeddings -o X_Nipples.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6033 -d /content/HS/embeddings -o 2Hands_Boobs.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6526 -d /content/HS/embeddings -o Anal_Missionary.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5160 -d /content/HS/embeddings -o Anal_Behind_Pulling_Arms.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5235 -d /content/HS/embeddings -o Make-up.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6242 -d /content/HS/embeddings -o Blowjob_Side.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5051 -d /content/HS/embeddings -o Blowjob_POV.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5066 -d /content/HS/embeddings -o Dick_Between_Breasts.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7002 -d /content/HS/embeddings -o Ball_In_Mouth.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/4597 -d /content/HS/embeddings -o Anal.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/5405 -d /content/HS/embeddings -o Missionary_Tied_Hands.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6770 -d /content/HS/embeddings -o Threesome.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6128 -d /content/HS/embeddings -o NSFW_Stuff.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/4738 -d /content/HS/embeddings -o CowGirl_Riding.pt

if Character:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6197 -d /content/HS/embeddings -o Makima.pt
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/6027 -d /content/HS/embeddings -o Power.pt

if Style:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/18187 -d /content/HS/embeddings -o hiten1.pt

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/SirVeggie/nixeu_embeddings/resolve/main/nixeu_extra.pt -d /content/HS/embeddings -o nixeu_extra.pt

#LyCORIS

if NSFW:
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/108549 -d /content/HS/models/LyCORIS -o SayaFrenchKiss.safetensors
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/110873 -d /content/HS/models/LyCORIS -o Saya-wiping mouth.safetensors


# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/55199 -d /content/HS/models/LyCORIS -o GoodHandsBeta2.safetensors

# %%
#@title #Start Stable Diffusion
#@markdown Run this cell to launch Stable Diffusion

# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/HS/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/HS/launch.py
# !sed -i -e 's/\"sd_model_checkpoint\"\,/\"sd_model_checkpoint\,sd_vae\,CLIP_stop_at_last_layers\"\,/g' /content/HS/modules/shared.py

# !mkdir /content/HS/extensions/deforum-for-automatic1111-webui/models

# !python launch.py --lowram --theme dark --no-half-vae --disable-nan-check --share --listen --xformers --enable-insecure-extension-access --gradio-queue --api --opt-sdp-attention

# %%
#@title #Download generated images
#@markdown Run this cell to download generated images
import zipfile
import os
from google.colab import files

output_to_drive = False #@param {'type':'boolean'}

if output_to_drive:
    from google.colab import drive
    if not os.path.exists('/content/drive/MyDrive'):
        drive.mount('/content/drive')
    output_dir = '/content/drive/MyDrive/Stable-Diffusion-output'
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    # !cp -r /content/HS/outputs/. {output_dir}
    print("Done..")
else:
    def create_zip(folder_path, zip_path):
        with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
            for root, _, files in os.walk(folder_path):
                for file in files:
                    file_path = os.path.join(root, file)
                    zipf.write(file_path, os.path.relpath(file_path, folder_path))

    folder_path = '/content/HS/outputs'
    zip_path = '/content/output.zip'
    create_zip(folder_path, zip_path)
    files.download(zip_path)
